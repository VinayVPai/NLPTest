# %%
import nltk as nl
import nltk.tokenize as nltok
f1=open('/Users/vinay_000/Documents/SPJain/Sentiment.txt',encoding="utf8").read()
tokens=nltok.word_tokenize(f1)
tokens
# Out:
# ['Han',
#  'wo',
#  'bhi',
#  'baat',
#  'hai',
#  'its',
#  'not',
#  '#',
#  'unionbudget2015',
#  'its',
#  '#',
#  'buredinkabudget',
#  'khana',
#  ',',
#  'cmputr',
#  ',',
#  'kapde',
#  ',',
#  'ghar',
#  'sab',
#  'mehenga',
#  '.',
#  'bewakuf',
#  'bnaya',
#  'sirf',
#  'inhone',
#  'public',
#  'movie',
#  'review',
#  ':',
#  '-',
#  'shamitabh',
#  '#',
#  'shamitabh',
#  '#',
#  'amitabhbachchan',
#  '#',
#  'moviereview',
#  'http',
#  ':',
#  '//t.co/xm7hsgfll6',
#  'ok',
#  'kachhua',
#  'sir',
#  'toh',
#  'students',
#  'ke',
#  'pakke',
#  'wale',
#  'dushman',
#  'hain',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  ':',
#  '@',
#  'salmaan',
#  'khan',
#  'tumhare',
#  'naam',
#  'k',
#  'pichey',
#  'khan',
#  'accha',
#  'nahi',
#  'lagtahai',
#  'hata',
#  'de',
#  'muslaman',
#  'ke',
#  'naam',
#  'ko',
#  'jo',
#  'itna',
#  'hi',
#  'bura',
#  'kagta',
#  'hai',
#  'islamic',
#  'dharm',
#  'to',
#  'abhi',
#  'chod',
#  'de',
#  'zarurat',
# ...

# %%
import operator
freq=nl.FreqDist(tokens)
TR=freq.values()
distinct_words=set(tokens)
doc_fr=dict.fromkeys(distinct_words,0)
sortedfreq=sorted(freq.items(),key=operator.itemgetter(1),reverse=True)
sortedfreq
# Out:
# [('.', 13682),
#  ('#', 3365),
#  ('to', 2650),
#  (',', 2620),
#  ('!', 2420),
#  ('the', 2419),
#  (':', 2386),
#  ('?', 2380),
#  ('hai', 2367),
#  ('...', 1954),
#  ('@', 1793),
#  ('ki', 1411),
#  ('ho', 1184),
#  ('in', 1144),
#  ('i', 1140),
#  ('me', 1136),
#  ('h', 1133),
#  ('is', 1083),
#  ('se', 1061),
#  ('ke', 1028),
#  ('ka', 1027),
#  ('a', 1014),
#  ('bhai', 994),
#  ('ko', 982),
#  ('and', 923),
#  ('of', 914),
#  (')', 910),
#  ('on', 848),
#  ('bhi', 841),
#  ('hi', 751),
#  ('someUSER', 742),
#  ('for', 726),
#  ('you', 703),
#  ('k', 691),
#  ('aap', 648),
#  ('kya', 646),
#  ('nahi', 633),
#  ('..', 620),
#  ('it', 619),
#  ('``', 584),
#  ("'s", 579),
#  ('ye', 567),
#  ('tha', 553),
#  ('he', 538),
#  ('na', 521),
#  (';', 510),
#  ('aur', 504),
#  ('kar', 500),
#  ('be', 495),
#  ('u', 494),
#  ('p', 468),
#  ('with', 462),
#  ('(', 460),
#  ('ek', 438),
#  ('nhi', 432),
#  ('or', 425),
#  ('http/URL', 401),
#  ('at', 391),
#  ('that', 391),
# ...
